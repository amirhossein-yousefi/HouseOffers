# %% [markdown]
# # Xgboost Model

# %% [markdown]
# If you don't want to do hyerparameter tuning ignore installing optuna package

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import optuna

# %%
data=pd.read_csv('immo_data_clean.csv')
handy_data=data.copy()

# %%
def get_rid_outl(df, list_num_var, percentile):
    """
    INPUT: 
    df: Dataframe
    list_num_var: List of the variables (columns) with outliers that need to be deleted
    percentile: float between 0 and 100: Percentage of the data that will be kept 
    
    OUTPUT:
    DataFrame with the defined amount of data. This means a DataFrame without outliers
    """
    
    perc_dict = {}
    for col in list_num_var: # first, calculate all the percentiles before removing any
        # row, otherwise you will remove more rows than necessary
        value_perc = np.nanpercentile(df[col], percentile)
        value_perc_dict = {col: value_perc}
        perc_dict.update(value_perc_dict)
        
    for var in list_num_var:    
        df = df.loc[(df[var] <= perc_dict[var]) ^ (df[var].isnull())] # include nan values
    
    return df

# %%
handy_data.drop(columns=['regionLevel3'], inplace=True)

# %%
handy_data.loc[handy_data.yearConstructed == "NO_INFORMATION", "yearConstructed"] = '0'
handy_data['yearConstructed']=handy_data['yearConstructed'].astype(int)
handy_data.loc[handy_data.yearConstructed == 0, "yearConstructed"] = None

# %%
handy_data['yearConstructed'] = handy_data['yearConstructed'].fillna(handy_data['yearConstructed'].median())

# %%
handy_data.drop(columns=['totalRent',
                 'serviceCharge',
                 'heatingCosts'], inplace=True)

# rename the response variable to rent
handy_data.rename(columns={'rent_incl_hc': 'rent'}, inplace=True)

# remove all rows where living space is 0
handy_data = handy_data[handy_data['livingSpace'] != 0]

# create a new variable for the rent/livingSpace (rent/m2)
handy_data['rent_m2'] = handy_data['rent'] / handy_data['livingSpace']

# get rid of outliers
handy_data = get_rid_outl(handy_data, ['rent_m2'], 99.8)

# %%
handy_data.typeOfFlat.replace(np.nan, 'NO_INFORMATION', inplace=True)
handy_data.interiorQuality.replace(np.nan, 'NO_INFORMATION', inplace=True)

# %%
# first transform all categorical values into dummies
list_cat_vars = handy_data.select_dtypes(include = ['object']).columns

for var in  list_cat_vars:
    # for each cat add dummy var, drop original column
    handy_data = pd.concat([handy_data.drop(var, axis=1), pd.get_dummies(handy_data[var], prefix=var, prefix_sep='_', drop_first=True)], axis=1)

handy_data.describe()
# Out:
#           Unnamed: 0  yearConstructed   noParkSpaces    livingSpace  \
# count  216043.000000    216043.000000  216043.000000  216043.000000
# mean   133560.294895      1966.829951       0.353383      70.739011
# std     77625.115921        42.516913       0.546004      26.509316
# min         0.000000      1000.000000       0.000000       1.000000
# 25%     66290.000000      1957.000000       0.000000      53.630000
# 50%    133074.000000      1972.000000       0.000000      66.220000
# 75%    200680.000000      1991.000000       1.000000      84.835000
# max    268848.000000      2020.000000       4.000000     180.000000
#
#             postcode        noRooms           rent        rent_m2  \
# count  216043.000000  216043.000000  216043.000000  216043.000000
# mean    36494.551043       2.567847     774.304525      11.049989
# std     27943.225308       0.899165     424.253415       4.570212
# min       852.000000       1.000000       1.000000       0.009455
# 25%      9119.000000       2.000000     474.000000       8.000000
# 50%     37603.000000       2.500000     645.000000       9.796944
# 75%     55543.000000       3.000000     955.005000      12.686179
# max     99998.000000       5.000000    2980.000000      44.444444
#
#        regionLevel1_Bayern  regionLevel1_Berlin  ...  lastRefurbish_2012  \
# count        216043.000000        216043.000000  ...       216043.000000
# mean              0.079674             0.038631  ...            0.009105
# std               0.270788             0.192715  ...            0.094983
# min               0.000000             0.000000  ...            0.000000
# 25%               0.000000             0.000000  ...            0.000000
# 50%               0.000000             0.000000  ...            0.000000
# 75%               0.000000             0.000000  ...            0.000000
# max               1.000000             1.000000  ...            1.000000
#
#        lastRefurbish_2013  lastRefurbish_2014  lastRefurbish_2015  \
# count       216043.000000       216043.000000       216043.000000
# mean             0.009628            0.013812            0.018182
# std              0.097648            0.116711            0.133608
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        lastRefurbish_2016  lastRefurbish_2017  lastRefurbish_2018  \
# count       216043.000000       216043.000000       216043.000000
# mean             0.022778            0.028499            0.051161
# std              0.149195            0.166394            0.220327
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        lastRefurbish_2019  lastRefurbish_2020  lastRefurbish_NO_INFORMATION
# count       216043.000000       216043.000000                 216043.000000
# mean             0.077887            0.014692                      0.682582
# std              0.267995            0.120315                      0.465473
# min              0.000000            0.000000                      0.000000
# 25%              0.000000            0.000000                      0.000000
# 50%              0.000000            0.000000                      1.000000
# 75%              0.000000            0.000000                      1.000000
# max              1.000000            1.000000                      1.000000
#
# [8 rows x 582 columns]

# %%
handy_data_new=handy_data[[feat for feat in handy_data.columns.to_list() if feat not in ['Unnamed: 0']] ]

# %%
y = handy_data_new['rent']
X = handy_data_new[[i for i in handy_data_new.columns if i not in ['rent', 'rent_m2']]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## I comment the bellow code as I did not have enough resource for optimizing the hyperparameters
# ### Note: if we want to do a hyperparameter tuning we must split dataset into 3 chunks of train,validation and test and we should choose our hyperparameters of model using validation not test in order to prevent model from over estimating and data leakage.
# ### At the end for evaluationg the performance of the model we must do a kfold on aggregation of train and test data  in order not to over estimate metrics
# ### I did not do these two parts as I I did not have enough computation resource but I put the code in bellow

# %% [raw]
# def objective(trial,data=[X_train, X_test, y_train, y_test]):
#
#     train_x, valid_x, train_y, valid_y = data
#     param = {'booster':'dart',
#         'tree_method':'hist',  # this parameter means using the not GPU when training our model to speedup the training process
#         'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
#         'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
#         'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
#         'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
#         'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.009,0.01,0.012,0.014,0.016,0.018, 0.02]),
#         'n_estimators': 4000,
#         'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17,20]),
#         'random_state': trial.suggest_categorical('random_state', [24, 48,2020]),
#         'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
#     }
#     model = xgb.XGBRegressor(**param,enable_categorical=True)
#     ## uncomment bellow for better estimation of the error
# #     kf = KFold(n_splits=5,random_state=48,shuffle=True)
#
# #     rmse=[]  # list contains rmse for each fold
# #     for trn_idx, test_idx in kf.split(train[columns],train['target']):
# #         X_tr,X_test=X_train_imputed.iloc[trn_idx],train[columns].iloc[test_idx]
# #         y_tr,y_test=train['target'].iloc[trn_idx],train['target'].iloc[test_idx]
# #         model = xgb.XGBRegressor(**Best_trial)
# #         model.fit(X_tr,y_tr,eval_set=[(X_test,y_test)],early_stopping_rounds=100,verbose=False)
# #         preds+=model.predict(test[columns])/kf.n_splits
# #         rmse.append(mean_squared_error(y_test, model.predict(X_test), squared=False))
# #         print(n+1,rmse[n])
# #         n+=1
# #     np.mean(rmse)
#
#     model.fit(train_x,train_y,eval_set=[(valid_x,valid_y)],early_stopping_rounds=100,verbose=False)
#
#     preds = model.predict(valid_x)
#
#     rmse = mean_squared_error(valid_y, preds,squared=False)
#
#     return rmse

# %% [raw]
# study = optuna.create_study(direction='minimize')
# study.optimize(objective, n_trials=50)
# print('Number of finished trials:', len(study.trials))
# print('Best trial:', study.best_trial.params)
# best_params=study.best_trial.params
# study.trials_dataframe()

# %% [raw]
# model = xgb.XGBRegressor(**best_params,enable_categorical=True,tree_method='hist')
# data=[X_train_imputed,X_valid_imputed,pd_y_train['totalRent'],pd_y_valid['totalRent']]
# train_x, valid_x, train_y, valid_y = data
# model.fit(train_x,train_y,eval_set=[(valid_x,valid_y)],early_stopping_rounds=100,verbose=False)
#
# preds = model.predict(valid_x)
#
# rmse = mean_squared_error(valid_y, preds,squared=False)
# print(rmse)

# %%
xg_model = xgb.XGBRegressor(n_estimators=1000, learning_rate=0.05,max_depth=30)
X_train, X_test, y_train, y_test
xg_model.fit(X_train, y_train, early_stopping_rounds=5,
             eval_set=[(X_test, y_test)])

max_estimators = len(xg_model.evals_result()['validation_0']['rmse'])
print(max_estimators)
pd.DataFrame(xg_model.evals_result()['validation_0']['rmse'], columns=['rmse']).plot()
# Out:
# [0]	validation_0-rmse:840.88129
# [1]	validation_0-rmse:800.94769
# [2]	validation_0-rmse:762.99487
# [3]	validation_0-rmse:726.99323
# [4]	validation_0-rmse:692.88586
# [5]	validation_0-rmse:660.54651
# [6]	validation_0-rmse:629.90753
# [7]	validation_0-rmse:600.82428
# [8]	validation_0-rmse:573.25427
# [9]	validation_0-rmse:547.19116
# [10]	validation_0-rmse:522.48718
# [11]	validation_0-rmse:499.08334
# [12]	validation_0-rmse:476.93021
# [13]	validation_0-rmse:455.96829
# [14]	validation_0-rmse:436.12234
# [15]	validation_0-rmse:417.41974
# [16]	validation_0-rmse:399.69171
# [17]	validation_0-rmse:382.98953
# [18]	validation_0-rmse:367.12830
# [19]	validation_0-rmse:352.14319
# [20]	validation_0-rmse:337.98694
# [21]	validation_0-rmse:324.70853
# [22]	validation_0-rmse:312.24509
# [23]	validation_0-rmse:300.45303
# [24]	validation_0-rmse:289.44931
# [25]	validation_0-rmse:278.98581
# [26]	validation_0-rmse:269.18012
# [27]	validation_0-rmse:259.94257
# [28]	validation_0-rmse:251.29964
# [29]	validation_0-rmse:243.23155
# [30]	validation_0-rmse:235.62212
# [31]	validation_0-rmse:228.50072
# [32]	validation_0-rmse:221.80072
# [33]	validation_0-rmse:215.57722
# [34]	validation_0-rmse:209.74605
# [35]	validation_0-rmse:204.29344
# [36]	validation_0-rmse:199.24150
# [37]	validation_0-rmse:194.49570
# [38]	validation_0-rmse:190.08252
# [39]	validation_0-rmse:185.98131
# [40]	validation_0-rmse:182.16956
# [41]	validation_0-rmse:178.65790
# [42]	validation_0-rmse:175.37125
# [43]	validation_0-rmse:172.34521
# [44]	validation_0-rmse:169.52164
# [45]	validation_0-rmse:166.89763
# [46]	validation_0-rmse:164.44882
# [47]	validation_0-rmse:162.15891
# [48]	validation_0-rmse:160.11464
# [49]	validation_0-rmse:158.15891
# [50]	validation_0-rmse:156.41985
# [51]	validation_0-rmse:154.82230
# [52]	validation_0-rmse:153.36438
# [53]	validation_0-rmse:151.97170
# [54]	validation_0-rmse:150.66475
# [55]	validation_0-rmse:149.50848
# [56]	validation_0-rmse:148.44487
# [57]	validation_0-rmse:147.43674
# [58]	validation_0-rmse:146.49788
# [59]	validation_0-rmse:145.64467
# [60]	validation_0-rmse:144.86112
# [61]	validation_0-rmse:144.14415
# [62]	validation_0-rmse:143.47028
# [63]	validation_0-rmse:142.85124
# [64]	validation_0-rmse:142.28511
# [65]	validation_0-rmse:141.75497
# [66]	validation_0-rmse:141.25140
# [67]	validation_0-rmse:140.78775
# [68]	validation_0-rmse:140.36665
# [69]	validation_0-rmse:139.98688
# [70]	validation_0-rmse:139.62450
# [71]	validation_0-rmse:139.30568
# [72]	validation_0-rmse:139.02425
# [73]	validation_0-rmse:138.75784
# [74]	validation_0-rmse:138.50772
# [75]	validation_0-rmse:138.26675
# [76]	validation_0-rmse:138.03040
# [77]	validation_0-rmse:137.83655
# [78]	validation_0-rmse:137.65070
# [79]	validation_0-rmse:137.47417
# [80]	validation_0-rmse:137.30382
# [81]	validation_0-rmse:137.16473
# [82]	validation_0-rmse:137.02669
# [83]	validation_0-rmse:136.89885
# [84]	validation_0-rmse:136.77518
# [85]	validation_0-rmse:136.67781
# [86]	validation_0-rmse:136.57967
# [87]	validation_0-rmse:136.47440
# [88]	validation_0-rmse:136.37759
# [89]	validation_0-rmse:136.28426
# [90]	validation_0-rmse:136.20161
# [91]	validation_0-rmse:136.12328
# [92]	validation_0-rmse:136.04411
# [93]	validation_0-rmse:135.98671
# [94]	validation_0-rmse:135.92293
# [95]	validation_0-rmse:135.86202
# [96]	validation_0-rmse:135.80525
# [97]	validation_0-rmse:135.74587
# [98]	validation_0-rmse:135.69507
# [99]	validation_0-rmse:135.64658
# [100]	validation_0-rmse:135.59592
# [101]	validation_0-rmse:135.55147
# [102]	validation_0-rmse:135.51454
# [103]	validation_0-rmse:135.47813
# [104]	validation_0-rmse:135.42764
# [105]	validation_0-rmse:135.39842
# [106]	validation_0-rmse:135.37079
# [107]	validation_0-rmse:135.33993
# [108]	validation_0-rmse:135.31287
# [109]	validation_0-rmse:135.28635
# [110]	validation_0-rmse:135.25862
# [111]	validation_0-rmse:135.23018
# [112]	validation_0-rmse:135.19731
# [113]	validation_0-rmse:135.16283
# [114]	validation_0-rmse:135.13573
# [115]	validation_0-rmse:135.09776
# [116]	validation_0-rmse:135.07521
# [117]	validation_0-rmse:135.03230
# [118]	validation_0-rmse:135.01500
# [119]	validation_0-rmse:134.98770
# [120]	validation_0-rmse:134.96408
# [121]	validation_0-rmse:134.92279
# [122]	validation_0-rmse:134.89554
# [123]	validation_0-rmse:134.86421
# [124]	validation_0-rmse:134.82526
# [125]	validation_0-rmse:134.79460
# [126]	validation_0-rmse:134.76454
# [127]	validation_0-rmse:134.75081
# [128]	validation_0-rmse:134.73912
# [129]	validation_0-rmse:134.71809
# [130]	validation_0-rmse:134.70165
# [131]	validation_0-rmse:134.68665
# [132]	validation_0-rmse:134.66550
# [133]	validation_0-rmse:134.65662
# [134]	validation_0-rmse:134.64053
# [135]	validation_0-rmse:134.63249
# [136]	validation_0-rmse:134.62143
# [137]	validation_0-rmse:134.59683
# [138]	validation_0-rmse:134.55176
# [139]	validation_0-rmse:134.51392
# [140]	validation_0-rmse:134.50336
# [141]	validation_0-rmse:134.47279
# [142]	validation_0-rmse:134.44504
# [143]	validation_0-rmse:134.42331
# [144]	validation_0-rmse:134.40102
# [145]	validation_0-rmse:134.38528
# [146]	validation_0-rmse:134.36435
# [147]	validation_0-rmse:134.34360
# [148]	validation_0-rmse:134.32950
# [149]	validation_0-rmse:134.32007
# [150]	validation_0-rmse:134.30992
# [151]	validation_0-rmse:134.29794
# [152]	validation_0-rmse:134.28966
# [153]	validation_0-rmse:134.27594
# [154]	validation_0-rmse:134.26480
# [155]	validation_0-rmse:134.25256
# [156]	validation_0-rmse:134.24153
# [157]	validation_0-rmse:134.23084
# [158]	validation_0-rmse:134.21008
# [159]	validation_0-rmse:134.20171
# [160]	validation_0-rmse:134.19218
# [161]	validation_0-rmse:134.18521
# [162]	validation_0-rmse:134.16061
# [163]	validation_0-rmse:134.15289
# [164]	validation_0-rmse:134.13496
# [165]	validation_0-rmse:134.12550
# [166]	validation_0-rmse:134.11180
# [167]	validation_0-rmse:134.08983
# [168]	validation_0-rmse:134.07700
# [169]	validation_0-rmse:134.07147
# [170]	validation_0-rmse:134.06113
# [171]	validation_0-rmse:134.05516
# [172]	validation_0-rmse:134.04718
# [173]	validation_0-rmse:134.03296
# [174]	validation_0-rmse:134.02745
# [175]	validation_0-rmse:134.02449
# [176]	validation_0-rmse:134.01854
# [177]	validation_0-rmse:133.98889
# [178]	validation_0-rmse:133.98274
# [179]	validation_0-rmse:133.97884
# [180]	validation_0-rmse:133.96721
# [181]	validation_0-rmse:133.96130
# [182]	validation_0-rmse:133.95579
# [183]	validation_0-rmse:133.94820
# [184]	validation_0-rmse:133.94571
# [185]	validation_0-rmse:133.92465
# [186]	validation_0-rmse:133.92030
# [187]	validation_0-rmse:133.91406
# [188]	validation_0-rmse:133.90445
# [189]	validation_0-rmse:133.89304
# [190]	validation_0-rmse:133.89029
# [191]	validation_0-rmse:133.88571
# [192]	validation_0-rmse:133.87955
# [193]	validation_0-rmse:133.87184
# [194]	validation_0-rmse:133.86906
# [195]	validation_0-rmse:133.85797
# [196]	validation_0-rmse:133.84488
# [197]	validation_0-rmse:133.83037
# [198]	validation_0-rmse:133.81265
# [199]	validation_0-rmse:133.80505
# [200]	validation_0-rmse:133.79552
# [201]	validation_0-rmse:133.79248
# [202]	validation_0-rmse:133.78995
# [203]	validation_0-rmse:133.78040
# [204]	validation_0-rmse:133.77351
# [205]	validation_0-rmse:133.76949
# [206]	validation_0-rmse:133.76651
# [207]	validation_0-rmse:133.75696
# [208]	validation_0-rmse:133.75411
# [209]	validation_0-rmse:133.75012
# [210]	validation_0-rmse:133.74126
# [211]	validation_0-rmse:133.72819
# [212]	validation_0-rmse:133.72638
# [213]	validation_0-rmse:133.71552
# [214]	validation_0-rmse:133.71332
# [215]	validation_0-rmse:133.70756
# [216]	validation_0-rmse:133.69659
# [217]	validation_0-rmse:133.68872
# [218]	validation_0-rmse:133.67940
# [219]	validation_0-rmse:133.67566
# [220]	validation_0-rmse:133.67305
# [221]	validation_0-rmse:133.67116
# [222]	validation_0-rmse:133.66901
# [223]	validation_0-rmse:133.66353
# [224]	validation_0-rmse:133.65262
# [225]	validation_0-rmse:133.64467
# [226]	validation_0-rmse:133.64145
# [227]	validation_0-rmse:133.63858
# [228]	validation_0-rmse:133.63577
# [229]	validation_0-rmse:133.63280
# [230]	validation_0-rmse:133.62849
# [231]	validation_0-rmse:133.62344
# [232]	validation_0-rmse:133.62151
# [233]	validation_0-rmse:133.61934
# [234]	validation_0-rmse:133.61618
# [235]	validation_0-rmse:133.61469
# [236]	validation_0-rmse:133.60969
# [237]	validation_0-rmse:133.60751
# [238]	validation_0-rmse:133.60487
# [239]	validation_0-rmse:133.60239
# [240]	validation_0-rmse:133.59598
# [241]	validation_0-rmse:133.59384
# [242]	validation_0-rmse:133.59033
# [243]	validation_0-rmse:133.58365
# [244]	validation_0-rmse:133.58049
# [245]	validation_0-rmse:133.57770
# [246]	validation_0-rmse:133.57567
# [247]	validation_0-rmse:133.57149
# [248]	validation_0-rmse:133.56863
# [249]	validation_0-rmse:133.56645
# [250]	validation_0-rmse:133.56422
# [251]	validation_0-rmse:133.55873
# [252]	validation_0-rmse:133.55353
# [253]	validation_0-rmse:133.55144
# [254]	validation_0-rmse:133.55000
# [255]	validation_0-rmse:133.54828
# [256]	validation_0-rmse:133.54469
# [257]	validation_0-rmse:133.54115
# [258]	validation_0-rmse:133.53595
# [259]	validation_0-rmse:133.52802
# [260]	validation_0-rmse:133.52589
# [261]	validation_0-rmse:133.52306
# [262]	validation_0-rmse:133.52132
# [263]	validation_0-rmse:133.51910
# [264]	validation_0-rmse:133.51726
# [265]	validation_0-rmse:133.51135
# [266]	validation_0-rmse:133.50621
# [267]	validation_0-rmse:133.50447
# [268]	validation_0-rmse:133.50182
# [269]	validation_0-rmse:133.49994
# [270]	validation_0-rmse:133.49797
# [271]	validation_0-rmse:133.49628
# [272]	validation_0-rmse:133.49152
# [273]	validation_0-rmse:133.49075
# [274]	validation_0-rmse:133.48897
# [275]	validation_0-rmse:133.48592
# [276]	validation_0-rmse:133.48325
# [277]	validation_0-rmse:133.47971
# [278]	validation_0-rmse:133.47609
# [279]	validation_0-rmse:133.47421
# [280]	validation_0-rmse:133.47220
# [281]	validation_0-rmse:133.46925
# [282]	validation_0-rmse:133.46574
# [283]	validation_0-rmse:133.46390
# [284]	validation_0-rmse:133.46249
# [285]	validation_0-rmse:133.45990
# [286]	validation_0-rmse:133.45595
# [287]	validation_0-rmse:133.45462
# [288]	validation_0-rmse:133.45352
# [289]	validation_0-rmse:133.44933
# [290]	validation_0-rmse:133.44655
# [291]	validation_0-rmse:133.44371
# [292]	validation_0-rmse:133.44196
# [293]	validation_0-rmse:133.43819
# [294]	validation_0-rmse:133.43545
# [295]	validation_0-rmse:133.43233
# [296]	validation_0-rmse:133.43072
# [297]	validation_0-rmse:133.42943
# [298]	validation_0-rmse:133.42749
# [299]	validation_0-rmse:133.41977
# [300]	validation_0-rmse:133.41521
# [301]	validation_0-rmse:133.41067
# [302]	validation_0-rmse:133.40936
# [303]	validation_0-rmse:133.40660
# [304]	validation_0-rmse:133.40407
# [305]	validation_0-rmse:133.40155
# [306]	validation_0-rmse:133.39981
# [307]	validation_0-rmse:133.39864
# [308]	validation_0-rmse:133.39531
# [309]	validation_0-rmse:133.39033
# [310]	validation_0-rmse:133.38737
# [311]	validation_0-rmse:133.38599
# [312]	validation_0-rmse:133.38474
# [313]	validation_0-rmse:133.38290
# [314]	validation_0-rmse:133.38203
# [315]	validation_0-rmse:133.38086
# [316]	validation_0-rmse:133.37689
# [317]	validation_0-rmse:133.37454
# [318]	validation_0-rmse:133.36987
# [319]	validation_0-rmse:133.36687
# [320]	validation_0-rmse:133.36536
# [321]	validation_0-rmse:133.36359
# [322]	validation_0-rmse:133.35997
# [323]	validation_0-rmse:133.35918
# [324]	validation_0-rmse:133.35763
# [325]	validation_0-rmse:133.35532
# [326]	validation_0-rmse:133.35176
# [327]	validation_0-rmse:133.34967
# [328]	validation_0-rmse:133.34741
# [329]	validation_0-rmse:133.34456
# [330]	validation_0-rmse:133.34189
# [331]	validation_0-rmse:133.33980
# [332]	validation_0-rmse:133.33629
# [333]	validation_0-rmse:133.33533
# [334]	validation_0-rmse:133.33221
# [335]	validation_0-rmse:133.33098
# [336]	validation_0-rmse:133.32715
# [337]	validation_0-rmse:133.32378
# [338]	validation_0-rmse:133.32237
# [339]	validation_0-rmse:133.32013
# [340]	validation_0-rmse:133.31898
# [341]	validation_0-rmse:133.31802
# [342]	validation_0-rmse:133.31673
# [343]	validation_0-rmse:133.31419
# [344]	validation_0-rmse:133.31302
# [345]	validation_0-rmse:133.31151
# [346]	validation_0-rmse:133.30841
# [347]	validation_0-rmse:133.30402
# [348]	validation_0-rmse:133.30017
# [349]	validation_0-rmse:133.29932
# [350]	validation_0-rmse:133.29332
# [351]	validation_0-rmse:133.29257
# [352]	validation_0-rmse:133.29010
# [353]	validation_0-rmse:133.28976
# [354]	validation_0-rmse:133.28825
# [355]	validation_0-rmse:133.28418
# [356]	validation_0-rmse:133.28310
# [357]	validation_0-rmse:133.27916
# [358]	validation_0-rmse:133.27832
# [359]	validation_0-rmse:133.27646
# [360]	validation_0-rmse:133.27222
# [361]	validation_0-rmse:133.26912
# [362]	validation_0-rmse:133.26753
# [363]	validation_0-rmse:133.26694
# [364]	validation_0-rmse:133.26634
# [365]	validation_0-rmse:133.26546
# [366]	validation_0-rmse:133.26486
# [367]	validation_0-rmse:133.26271
# [368]	validation_0-rmse:133.25992
# [369]	validation_0-rmse:133.25877
# [370]	validation_0-rmse:133.25572
# [371]	validation_0-rmse:133.25377
# [372]	validation_0-rmse:133.25262
# [373]	validation_0-rmse:133.25076
# [374]	validation_0-rmse:133.24982
# [375]	validation_0-rmse:133.24620
# [376]	validation_0-rmse:133.24219
# [377]	validation_0-rmse:133.23860
# [378]	validation_0-rmse:133.23764
# [379]	validation_0-rmse:133.23675
# [380]	validation_0-rmse:133.23538
# [381]	validation_0-rmse:133.23395
# [382]	validation_0-rmse:133.23320
# [383]	validation_0-rmse:133.23038
# [384]	validation_0-rmse:133.22842
# [385]	validation_0-rmse:133.22748
# [386]	validation_0-rmse:133.22342
# [387]	validation_0-rmse:133.22014
# [388]	validation_0-rmse:133.21918
# [389]	validation_0-rmse:133.21870
# [390]	validation_0-rmse:133.21606
# [391]	validation_0-rmse:133.21558
# [392]	validation_0-rmse:133.21451
# [393]	validation_0-rmse:133.21236
# [394]	validation_0-rmse:133.21166
# [395]	validation_0-rmse:133.21010
# [396]	validation_0-rmse:133.20714
# [397]	validation_0-rmse:133.20691
# [398]	validation_0-rmse:133.20480
# [399]	validation_0-rmse:133.20416
# [400]	validation_0-rmse:133.20204
# [401]	validation_0-rmse:133.19690
# [402]	validation_0-rmse:133.19420
# [403]	validation_0-rmse:133.19330
# [404]	validation_0-rmse:133.19252
# [405]	validation_0-rmse:133.19159
# [406]	validation_0-rmse:133.19080
# [407]	validation_0-rmse:133.18890
# [408]	validation_0-rmse:133.18683
# [409]	validation_0-rmse:133.18658
# [410]	validation_0-rmse:133.18399
# [411]	validation_0-rmse:133.18315
# [412]	validation_0-rmse:133.18253
# [413]	validation_0-rmse:133.18127
# [414]	validation_0-rmse:133.17923
# [415]	validation_0-rmse:133.17694
# [416]	validation_0-rmse:133.17586
# [417]	validation_0-rmse:133.17487
# [418]	validation_0-rmse:133.17409
# [419]	validation_0-rmse:133.17337
# [420]	validation_0-rmse:133.17271
# [421]	validation_0-rmse:133.17133
# [422]	validation_0-rmse:133.16986
# [423]	validation_0-rmse:133.16728
# [424]	validation_0-rmse:133.16505
# [425]	validation_0-rmse:133.16417
# [426]	validation_0-rmse:133.16161
# [427]	validation_0-rmse:133.15861
# [428]	validation_0-rmse:133.15788
# [429]	validation_0-rmse:133.15729
# [430]	validation_0-rmse:133.15616
# [431]	validation_0-rmse:133.15465
# [432]	validation_0-rmse:133.15338
# [433]	validation_0-rmse:133.14993
# [434]	validation_0-rmse:133.14845
# [435]	validation_0-rmse:133.14651
# [436]	validation_0-rmse:133.14616
# [437]	validation_0-rmse:133.14505
# [438]	validation_0-rmse:133.14165
# [439]	validation_0-rmse:133.14085
# [440]	validation_0-rmse:133.14008
# [441]	validation_0-rmse:133.13864
# [442]	validation_0-rmse:133.13619
# [443]	validation_0-rmse:133.13411
# [444]	validation_0-rmse:133.13350
# [445]	validation_0-rmse:133.13252
# [446]	validation_0-rmse:133.13297
# [447]	validation_0-rmse:133.13139
# [448]	validation_0-rmse:133.13007
# [449]	validation_0-rmse:133.12810
# [450]	validation_0-rmse:133.12730
# [451]	validation_0-rmse:133.12668
# [452]	validation_0-rmse:133.12595
# [453]	validation_0-rmse:133.12488
# [454]	validation_0-rmse:133.12248
# [455]	validation_0-rmse:133.12205
# [456]	validation_0-rmse:133.12106
# [457]	validation_0-rmse:133.12059
# [458]	validation_0-rmse:133.11795
# [459]	validation_0-rmse:133.11638
# [460]	validation_0-rmse:133.11441
# [461]	validation_0-rmse:133.11311
# [462]	validation_0-rmse:133.11221
# [463]	validation_0-rmse:133.11142
# [464]	validation_0-rmse:133.10924
# [465]	validation_0-rmse:133.10818
# [466]	validation_0-rmse:133.10625
# [467]	validation_0-rmse:133.10288
# [468]	validation_0-rmse:133.10031
# [469]	validation_0-rmse:133.09827
# [470]	validation_0-rmse:133.09663
# [471]	validation_0-rmse:133.09560
# [472]	validation_0-rmse:133.09505
# [473]	validation_0-rmse:133.09438
# [474]	validation_0-rmse:133.09288
# [475]	validation_0-rmse:133.09247
# [476]	validation_0-rmse:133.09016
# [477]	validation_0-rmse:133.08756
# [478]	validation_0-rmse:133.08640
# [479]	validation_0-rmse:133.08443
# [480]	validation_0-rmse:133.08397
# [481]	validation_0-rmse:133.08318
# [482]	validation_0-rmse:133.08157
# [483]	validation_0-rmse:133.08025
# [484]	validation_0-rmse:133.07933
# [485]	validation_0-rmse:133.07817
# [486]	validation_0-rmse:133.07564
# [487]	validation_0-rmse:133.07491
# [488]	validation_0-rmse:133.07349
# [489]	validation_0-rmse:133.07184
# [490]	validation_0-rmse:133.07062
# [491]	validation_0-rmse:133.06865
# [492]	validation_0-rmse:133.06699
# [493]	validation_0-rmse:133.06511
# [494]	validation_0-rmse:133.06389
# [495]	validation_0-rmse:133.06287
# [496]	validation_0-rmse:133.06186
# [497]	validation_0-rmse:133.06166
# [498]	validation_0-rmse:133.05934
# [499]	validation_0-rmse:133.05864
# [500]	validation_0-rmse:133.05832
# [501]	validation_0-rmse:133.05739
# [502]	validation_0-rmse:133.05682
# [503]	validation_0-rmse:133.05533
# [504]	validation_0-rmse:133.05417
# [505]	validation_0-rmse:133.05231
# [506]	validation_0-rmse:133.05208
# [507]	validation_0-rmse:133.05115
# [508]	validation_0-rmse:133.05061
# [509]	validation_0-rmse:133.04935
# [510]	validation_0-rmse:133.04765
# [511]	validation_0-rmse:133.04568
# [512]	validation_0-rmse:133.04367
# [513]	validation_0-rmse:133.04170
# [514]	validation_0-rmse:133.04123
# [515]	validation_0-rmse:133.03970
# [516]	validation_0-rmse:133.03857
# [517]	validation_0-rmse:133.03786
# [518]	validation_0-rmse:133.03630
# [519]	validation_0-rmse:133.03422
# [520]	validation_0-rmse:133.03278
# [521]	validation_0-rmse:133.03198
# [522]	validation_0-rmse:133.03072
# [523]	validation_0-rmse:133.03005
# [524]	validation_0-rmse:133.02962
# [525]	validation_0-rmse:133.02882
# [526]	validation_0-rmse:133.02727
# [527]	validation_0-rmse:133.02612
# [528]	validation_0-rmse:133.02541
# [529]	validation_0-rmse:133.02473
# [530]	validation_0-rmse:133.02359
# [531]	validation_0-rmse:133.02303
# [532]	validation_0-rmse:133.02232
# [533]	validation_0-rmse:133.02101
# [534]	validation_0-rmse:133.02060
# [535]	validation_0-rmse:133.01849
# [536]	validation_0-rmse:133.01749
# [537]	validation_0-rmse:133.01710
# [538]	validation_0-rmse:133.01648
# [539]	validation_0-rmse:133.01552
# [540]	validation_0-rmse:133.01465
# [541]	validation_0-rmse:133.01355
# [542]	validation_0-rmse:133.01193
# [543]	validation_0-rmse:133.01102
# [544]	validation_0-rmse:133.01086
# [545]	validation_0-rmse:133.01036
# [546]	validation_0-rmse:133.00906
# [547]	validation_0-rmse:133.00896
# [548]	validation_0-rmse:133.00835
# [549]	validation_0-rmse:133.00792
# [550]	validation_0-rmse:133.00734
# [551]	validation_0-rmse:133.00691
# [552]	validation_0-rmse:133.00583
# [553]	validation_0-rmse:133.00458
# [554]	validation_0-rmse:133.00406
# [555]	validation_0-rmse:133.00346
# [556]	validation_0-rmse:133.00255
# [557]	validation_0-rmse:133.00200
# [558]	validation_0-rmse:133.00159
# [559]	validation_0-rmse:133.00073
# [560]	validation_0-rmse:133.00038
# [561]	validation_0-rmse:133.00009
# [562]	validation_0-rmse:132.99960
# [563]	validation_0-rmse:132.99928
# [564]	validation_0-rmse:132.99837
# [565]	validation_0-rmse:132.99814
# [566]	validation_0-rmse:132.99629
# [567]	validation_0-rmse:132.99478
# [568]	validation_0-rmse:132.99333
# [569]	validation_0-rmse:132.99260
# [570]	validation_0-rmse:132.99222
# [571]	validation_0-rmse:132.99162
# [572]	validation_0-rmse:132.99100
# [573]	validation_0-rmse:132.98982
# [574]	validation_0-rmse:132.98816
# [575]	validation_0-rmse:132.98741
# [576]	validation_0-rmse:132.98685
# [577]	validation_0-rmse:132.98573
# [578]	validation_0-rmse:132.98496
# [579]	validation_0-rmse:132.98430
# [580]	validation_0-rmse:132.98357
# [581]	validation_0-rmse:132.98337
# [582]	validation_0-rmse:132.98215
# [583]	validation_0-rmse:132.98171
# [584]	validation_0-rmse:132.98131
# [585]	validation_0-rmse:132.98074
# [586]	validation_0-rmse:132.98058
# [587]	validation_0-rmse:132.97957
# [588]	validation_0-rmse:132.97871
# [589]	validation_0-rmse:132.97807
# [590]	validation_0-rmse:132.97697
# [591]	validation_0-rmse:132.97647
# [592]	validation_0-rmse:132.97562
# [593]	validation_0-rmse:132.97502
# [594]	validation_0-rmse:132.97443
# [595]	validation_0-rmse:132.97328
# [596]	validation_0-rmse:132.97212
# [597]	validation_0-rmse:132.97121
# [598]	validation_0-rmse:132.97069
# [599]	validation_0-rmse:132.97008
# [600]	validation_0-rmse:132.96945
# [601]	validation_0-rmse:132.96777
# [602]	validation_0-rmse:132.96736
# [603]	validation_0-rmse:132.96559
# [604]	validation_0-rmse:132.96458
# [605]	validation_0-rmse:132.96367
# [606]	validation_0-rmse:132.96204
# [607]	validation_0-rmse:132.96140
# [608]	validation_0-rmse:132.96056
# [609]	validation_0-rmse:132.96007
# [610]	validation_0-rmse:132.95984
# [611]	validation_0-rmse:132.95883
# [612]	validation_0-rmse:132.95795
# [613]	validation_0-rmse:132.95755
# [614]	validation_0-rmse:132.95625
# [615]	validation_0-rmse:132.95604
# [616]	validation_0-rmse:132.95575
# [617]	validation_0-rmse:132.95512
# [618]	validation_0-rmse:132.95468
# [619]	validation_0-rmse:132.95450
# [620]	validation_0-rmse:132.95416
# [621]	validation_0-rmse:132.95366
# [622]	validation_0-rmse:132.95351
# [623]	validation_0-rmse:132.95285
# [624]	validation_0-rmse:132.95245
# [625]	validation_0-rmse:132.95229
# [626]	validation_0-rmse:132.95212
# [627]	validation_0-rmse:132.95186
# [628]	validation_0-rmse:132.95027
# [629]	validation_0-rmse:132.94949
# [630]	validation_0-rmse:132.94936
# [631]	validation_0-rmse:132.94871
# [632]	validation_0-rmse:132.94856
# [633]	validation_0-rmse:132.94797
# [634]	validation_0-rmse:132.94777
# [635]	validation_0-rmse:132.94720
# [636]	validation_0-rmse:132.94659
# [637]	validation_0-rmse:132.94608
# [638]	validation_0-rmse:132.94513
# [639]	validation_0-rmse:132.94524
# [640]	validation_0-rmse:132.94464
# [641]	validation_0-rmse:132.94467
# [642]	validation_0-rmse:132.94403
# [643]	validation_0-rmse:132.94371
# [644]	validation_0-rmse:132.94330
# [645]	validation_0-rmse:132.94290
# [646]	validation_0-rmse:132.94225
# [647]	validation_0-rmse:132.94127
# [648]	validation_0-rmse:132.94101
# [649]	validation_0-rmse:132.94073
# [650]	validation_0-rmse:132.94046
# [651]	validation_0-rmse:132.93910
# [652]	validation_0-rmse:132.93874
# [653]	validation_0-rmse:132.93849
# [654]	validation_0-rmse:132.93834
# [655]	validation_0-rmse:132.93800
# [656]	validation_0-rmse:132.93780
# [657]	validation_0-rmse:132.93715
# [658]	validation_0-rmse:132.93660
# [659]	validation_0-rmse:132.93613
# [660]	validation_0-rmse:132.93558
# [661]	validation_0-rmse:132.93538
# [662]	validation_0-rmse:132.93530
# [663]	validation_0-rmse:132.93503
# [664]	validation_0-rmse:132.93358
# [665]	validation_0-rmse:132.93300
# [666]	validation_0-rmse:132.93257
# [667]	validation_0-rmse:132.93179
# [668]	validation_0-rmse:132.93127
# [669]	validation_0-rmse:132.93068
# [670]	validation_0-rmse:132.93018
# [671]	validation_0-rmse:132.92978
# [672]	validation_0-rmse:132.92966
# [673]	validation_0-rmse:132.92859
# [674]	validation_0-rmse:132.92786
# [675]	validation_0-rmse:132.92754
# [676]	validation_0-rmse:132.92676
# [677]	validation_0-rmse:132.92645
# [678]	validation_0-rmse:132.92615
# [679]	validation_0-rmse:132.92551
# [680]	validation_0-rmse:132.92526
# [681]	validation_0-rmse:132.92438
# [682]	validation_0-rmse:132.92418
# [683]	validation_0-rmse:132.92403
# [684]	validation_0-rmse:132.92274
# [685]	validation_0-rmse:132.92259
# [686]	validation_0-rmse:132.92158
# [687]	validation_0-rmse:132.92151
# [688]	validation_0-rmse:132.92108
# [689]	validation_0-rmse:132.92117
# [690]	validation_0-rmse:132.92108
# [691]	validation_0-rmse:132.92047
# [692]	validation_0-rmse:132.92027
# [693]	validation_0-rmse:132.91995
# [694]	validation_0-rmse:132.91952
# [695]	validation_0-rmse:132.91907
# [696]	validation_0-rmse:132.91882
# [697]	validation_0-rmse:132.91872
# [698]	validation_0-rmse:132.91826
# [699]	validation_0-rmse:132.91809
# [700]	validation_0-rmse:132.91757
# [701]	validation_0-rmse:132.91702
# [702]	validation_0-rmse:132.91634
# [703]	validation_0-rmse:132.91548
# [704]	validation_0-rmse:132.91511
# [705]	validation_0-rmse:132.91399
# [706]	validation_0-rmse:132.91386
# [707]	validation_0-rmse:132.91341
# [708]	validation_0-rmse:132.91310
# [709]	validation_0-rmse:132.91281
# [710]	validation_0-rmse:132.91263
# [711]	validation_0-rmse:132.91234
# [712]	validation_0-rmse:132.91183
# [713]	validation_0-rmse:132.91118
# [714]	validation_0-rmse:132.91109
# [715]	validation_0-rmse:132.91072
# [716]	validation_0-rmse:132.91042
# [717]	validation_0-rmse:132.91002
# [718]	validation_0-rmse:132.90929
# [719]	validation_0-rmse:132.90851
# [720]	validation_0-rmse:132.90753
# [721]	validation_0-rmse:132.90724
# [722]	validation_0-rmse:132.90642
# [723]	validation_0-rmse:132.90585
# [724]	validation_0-rmse:132.90569
# [725]	validation_0-rmse:132.90529
# [726]	validation_0-rmse:132.90505
# [727]	validation_0-rmse:132.90508
# [728]	validation_0-rmse:132.90468
# [729]	validation_0-rmse:132.90420
# [730]	validation_0-rmse:132.90410
# [731]	validation_0-rmse:132.90359
# [732]	validation_0-rmse:132.90335
# [733]	validation_0-rmse:132.90312
# [734]	validation_0-rmse:132.90291
# [735]	validation_0-rmse:132.90257
# [736]	validation_0-rmse:132.90233
# [737]	validation_0-rmse:132.90158
# [738]	validation_0-rmse:132.90096
# [739]	validation_0-rmse:132.90089
# [740]	validation_0-rmse:132.90051
# [741]	validation_0-rmse:132.90002
# [742]	validation_0-rmse:132.90013
# [743]	validation_0-rmse:132.90018
# [744]	validation_0-rmse:132.90022
# [745]	validation_0-rmse:132.89995
# [746]	validation_0-rmse:132.89877
# [747]	validation_0-rmse:132.89763
# [748]	validation_0-rmse:132.89670
# [749]	validation_0-rmse:132.89583
# [750]	validation_0-rmse:132.89511
# [751]	validation_0-rmse:132.89397
# [752]	validation_0-rmse:132.89293
# [753]	validation_0-rmse:132.89168
# [754]	validation_0-rmse:132.89105
# [755]	validation_0-rmse:132.88988
# [756]	validation_0-rmse:132.88902
# [757]	validation_0-rmse:132.88794
# [758]	validation_0-rmse:132.88707
# [759]	validation_0-rmse:132.88681
# [760]	validation_0-rmse:132.88684
# [761]	validation_0-rmse:132.88701
# [762]	validation_0-rmse:132.88722
# [763]	validation_0-rmse:132.88727
# [764]	validation_0-rmse:132.88709
# 765
# <AxesSubplot:>

# %%
from sklearn.metrics import r2_score
y_pred=xg_model.predict(X_test)
r2_score(y_true=y_test, y_pred=y_pred)
r2_score
# Out:
# 0.9022735400918777

# %%
(pd.Series(xg_model.feature_importances_, index=X_train.columns.to_list())
   .nlargest(15)
   .plot(kind='barh'))
# Out:
# <AxesSubplot:>

# %% [markdown]
# The bellow cell is done according no to over estimate the model performance using random chunk of test data at each iteration for evaluation and the mean the result for final

# %%
from xgboost import cv
params={'n_estimators':1000, 'learning_rate':0.05,'max_depth':30}
data_dmatrix = xgb.DMatrix(data=X,label=y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  
xgb_cv = cv(dtrain=data_dmatrix, params=params, nfold=10,
                    num_boost_round=50, early_stopping_rounds=10, metrics=["rmse",'mae'], as_pandas=True, seed=123)
# Out:
# [15:27:19] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:28:09] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:29:03] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:29:48] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:30:20] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:30:47] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:31:31] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:32:11] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:32:56] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [15:33:51] WARNING: ../src/learner.cc:573:
# Parameters: { "n_estimators" } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
